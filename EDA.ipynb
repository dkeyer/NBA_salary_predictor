# %% [markdown]
# # Capstone EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#imports

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Is it possible to predict NBA player salaries based on a player's game statistics? If so, which factors are most closely correlated with the salary of a player?

# %% [markdown]
# # Reading in Data, Dropping Nulls, Merging Dataframes

# %%
twenty_stats = pd.read_csv('./datasets/19-20_stats.csv')
#Reading in data from 2019-2020, all subsequent reading in of data will be similar i.e. will be named with the year in which
#the season ended

# %%
twenty_stats.insert(2, 'Season', '19-20')
#Adding season column

# %%
twenty_stats = twenty_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
nineteen_stats = pd.read_csv('./datasets/18-19_stats.csv')

# %%
nineteen_stats.insert(2, 'Season', '18-19')
nineteen_stats.head()
#Adding season column
# Out:
#    Rk        Player Season Pos  Age   Tm   G  GS    MP   FG  ...    FT%  ORB  \
# 0   1  Álex Abrines  18-19  SG   25  OKC  31   2  19.0  1.8  ...  0.923  0.2
# 1   2    Quincy Acy  18-19  PF   28  PHO  10   0  12.3  0.4  ...  0.700  0.3
# 2   3  Jaylen Adams  18-19  PG   22  ATL  34   1  12.6  1.1  ...  0.778  0.3
# 3   4  Steven Adams  18-19   C   25  OKC  80  80  33.4  6.0  ...  0.500  4.9
# 4   5   Bam Adebayo  18-19   C   21  MIA  82  28  23.3  3.4  ...  0.735  2.0
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 31 columns]

# %%
nineteen_stats = nineteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
eighteen_stats = pd.read_csv('./datasets/17-18_stats.csv')

# %%
eighteen_stats.insert(2, 'Season', '17-18')
eighteen_stats.head()
#Adding season column
# Out:
#    Rk         Player Season Pos  Age   Tm   G  GS    MP   FG  ...    FT%  ORB  \
# 0   1   Álex Abrines  17-18  SG   24  OKC  75   8  15.1  1.5  ...  0.848  0.3
# 1   2     Quincy Acy  17-18  PF   27  BRK  70   8  19.4  1.9  ...  0.817  0.6
# 2   3   Steven Adams  17-18   C   24  OKC  76  76  32.7  5.9  ...  0.559  5.1
# 3   4    Bam Adebayo  17-18   C   20  MIA  69  19  19.8  2.5  ...  0.721  1.7
# 4   5  Arron Afflalo  17-18  SG   32  ORL  53   3  12.9  1.2  ...  0.846  0.1
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.2  1.5  0.4  0.5  0.1  0.3  1.7   4.7
# 1  3.1  3.7  0.8  0.5  0.4  0.9  2.1   5.9
# 2  4.0  9.0  1.2  1.2  1.0  1.7  2.8  13.9
# 3  3.8  5.5  1.5  0.5  0.6  1.0  2.0   6.9
# 4  1.2  1.2  0.6  0.1  0.2  0.4  1.1   3.4
#
# [5 rows x 31 columns]

# %%
eighteen_stats = eighteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
seventeen_stats = pd.read_csv('./datasets/16-17_stats.csv')

# %%
seventeen_stats.insert(2, 'Season', '16-17')
seventeen_stats.head()
#Adding season column
# Out:
#    Rk        Player Season Pos  Age   Tm   G  GS    MP   FG  ...    FT%  ORB  \
# 0   1  Álex Abrines  16-17  SG   23  OKC  68   6  15.5  2.0  ...  0.898  0.3
# 1   2    Quincy Acy  16-17  PF   26  TOT  38   1  14.7  1.8  ...  0.750  0.5
# 2   2    Quincy Acy  16-17  PF   26  DAL   6   0   8.0  0.8  ...  0.667  0.3
# 3   2    Quincy Acy  16-17  PF   26  BRK  32   1  15.9  2.0  ...  0.754  0.6
# 4   3  Steven Adams  16-17   C   23  OKC  80  80  29.9  4.7  ...  0.611  3.5
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.0  1.3  0.6  0.5  0.1  0.5  1.7   6.0
# 1  2.5  3.0  0.5  0.4  0.4  0.6  1.8   5.8
# 2  1.0  1.3  0.0  0.0  0.0  0.3  1.5   2.2
# 3  2.8  3.3  0.6  0.4  0.5  0.6  1.8   6.5
# 4  4.2  7.7  1.1  1.1  1.0  1.8  2.4  11.3
#
# [5 rows x 31 columns]

# %%
seventeen_stats = seventeen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
sixteen_stats = pd.read_csv('./datasets/15-16_stats.csv')

# %%
sixteen_stats.insert(2, 'Season', '15-16')
sixteen_stats.head()
#Adding season column
# Out:
#    Rk         Player Season Pos  Age   Tm   G  GS    MP   FG  ...    FT%  ORB  \
# 0   1     Quincy Acy  15-16  PF   25  SAC  59  29  14.8  2.0  ...  0.735  1.1
# 1   2   Jordan Adams  15-16  SG   21  MEM   2   0   7.5  1.0  ...  0.600  0.0
# 2   3   Steven Adams  15-16   C   22  OKC  80  80  25.2  3.3  ...  0.582  2.7
# 3   4  Arron Afflalo  15-16  SG   30  NYK  71  57  33.4  5.0  ...  0.840  0.3
# 4   5  Alexis Ajinça  15-16   C   27  NOP  59  17  14.6  2.5  ...  0.839  1.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.1  3.2  0.5  0.5  0.4  0.5  1.7   5.2
# 1  1.0  1.0  1.5  1.5  0.0  1.0  1.0   3.5
# 2  3.9  6.7  0.8  0.5  1.1  1.1  2.8   8.0
# 3  3.4  3.7  2.0  0.4  0.1  1.2  2.0  12.8
# 4  3.3  4.6  0.5  0.3  0.6  0.9  2.3   6.0
#
# [5 rows x 31 columns]

# %%
sixteen_stats = sixteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %% [markdown]
# Above, just loading in all of the statistics of the data I will use over the five years

# %%
twenty_salary = pd.read_csv('./datasets/NBA_Player_salaries_1920.csv')
#Reading in salary data from 2019-2020

# %%
twenty_salary_cond = twenty_salary[['Player', '2019-20']]
twenty_salary_cond.head()
#Condensing the dataframe, as I am only concerned with 2019-2020 salary for now
# Out:
#               Player      2019-20
# 0      Stephen Curry  $40,231,758
# 1         Chris Paul  $38,506,482
# 2  Russell Westbrook  $38,178,000
# 3          John Wall  $37,800,000
# 4       James Harden  $37,800,000

# %%
twenty_stats['Player'] = twenty_stats['Player'].dropna()
#Dropping null values

# %%
twenty_stats_and_sal = pd.merge(left=twenty_stats, right=twenty_salary_cond, how='left', on='Player')
#Merging stats from 2019-2020 with salaries

# %%
twenty_stats_and_sal = twenty_stats_and_sal.drop(['Rk'], axis=1)
#Rank column is unnecessary, so dropping it

# %%
twenty_stats_and_sal.head()
# Out:
#                      Player Season Pos   Age   Tm     G    GS    MP   FG  \
# 0              Steven Adams  19-20   C  26.0  OKC  63.0  63.0  26.7  4.5
# 1               Bam Adebayo  19-20  PF  22.0  MIA  72.0  72.0  33.6  6.1
# 2         LaMarcus Aldridge  19-20   C  34.0  SAS  53.0  53.0  33.1  7.4
# 3            Kyle Alexander  19-20  PF  23.0  MIA   2.0   0.0   6.5  0.5
# 4  Nickeil Alexander-Walker  19-20  SG  21.0  NOP  47.0   1.0  12.6  2.1
#
#     FGA  ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS      2019-20
# 0   7.6  ...  3.3  6.0   9.3  2.3  0.8  1.1  1.5  1.9  10.9  $25,842,697
# 1  11.0  ...  2.4  7.8  10.2  5.1  1.1  1.3  2.8  2.5  15.9   $3,454,080
# 2  15.0  ...  1.9  5.5   7.4  2.4  0.7  1.6  1.4  2.4  18.9  $26,000,000
# 3   1.0  ...  1.0  0.5   1.5  0.0  0.0  0.0  0.5  0.5   1.0          NaN
# 4   5.7  ...  0.2  1.6   1.8  1.9  0.4  0.2  1.1  1.2   5.7   $2,964,840
#
# [5 rows x 31 columns]

# %%
twenty_stats_and_sal['Player'].isnull().sum()
#These are the players in the salary dataframe and not in the stats dataframe
# Out:
# 28

# %%
twenty_stats_and_sal = twenty_stats_and_sal.drop_duplicates(subset=['Player'], keep='first')
#There are still some duplicates we have to deal with. It appears that the first value of a duplicate player is his true
#salary (highest), so we will keep that and drop the rest

# %%
twenty_stats_and_sal['2019-20'].isnull().sum()
#We don't have salaries for 67 players, so we will have to drop them
# Out:
# 67

# %%
twenty_stats_and_sal = twenty_stats_and_sal.drop([132])
#Dropping totally null row

# %%
twenty_stats_and_sal = twenty_stats_and_sal[twenty_stats_and_sal['2019-20'].notna()]
#Dropping players that are without a salary

# %%
twenty_stats_and_sal.head()
#Previous null salary values are not there
# Out:
#                      Player Season Pos   Age   Tm     G    GS    MP   FG  \
# 0              Steven Adams  19-20   C  26.0  OKC  63.0  63.0  26.7  4.5
# 1               Bam Adebayo  19-20  PF  22.0  MIA  72.0  72.0  33.6  6.1
# 2         LaMarcus Aldridge  19-20   C  34.0  SAS  53.0  53.0  33.1  7.4
# 4  Nickeil Alexander-Walker  19-20  SG  21.0  NOP  47.0   1.0  12.6  2.1
# 5             Grayson Allen  19-20  SG  24.0  MEM  38.0   0.0  18.9  3.1
#
#     FGA  ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS      2019-20
# 0   7.6  ...  3.3  6.0   9.3  2.3  0.8  1.1  1.5  1.9  10.9  $25,842,697
# 1  11.0  ...  2.4  7.8  10.2  5.1  1.1  1.3  2.8  2.5  15.9   $3,454,080
# 2  15.0  ...  1.9  5.5   7.4  2.4  0.7  1.6  1.4  2.4  18.9  $26,000,000
# 4   5.7  ...  0.2  1.6   1.8  1.9  0.4  0.2  1.1  1.2   5.7   $2,964,840
# 5   6.6  ...  0.2  2.0   2.2  1.4  0.3  0.1  0.9  1.4   8.7   $2,429,400
#
# [5 rows x 31 columns]

# %%
twenty_stats_and_sal.describe()
# Out:
#               Age           G          GS          MP          FG         FGA  \
# count  463.000000  463.000000  463.000000  463.000000  463.000000  463.000000
# mean    25.941685   45.438445   21.937365   20.568035    3.399784    7.450540
# std      4.204570   21.161203   24.623889    8.863900    2.287776    4.795122
# min     19.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     23.000000   29.000000    1.000000   13.500000    1.700000    3.850000
# 50%     25.000000   53.000000    9.000000   20.100000    2.900000    6.100000
# 75%     29.000000   63.000000   44.000000   28.200000    4.550000   10.350000
# max     43.000000   74.000000   73.000000   37.500000   10.900000   22.900000
#
#               FG%          3P         3PA         3P%  ...         FT%  \
# count  461.000000  463.000000  463.000000  442.000000  ...  452.000000
# mean     0.450733    1.003672    2.848164    0.317041  ...    0.748967
# ...

# %%
twenty_stats_and_sal['2019-20'] = twenty_stats_and_sal['2019-20'].str.replace(',', '')
#Taking steps to turn column into integer

# %%
twenty_stats_and_sal['2019-20'] = twenty_stats_and_sal['2019-20'].str.replace('$', '')

# %%
twenty_stats_and_sal['2019-20'] = twenty_stats_and_sal['2019-20'].astype(int)
#Turning salary into an integer

# %%
twenty_stats_and_sal.corr()['2019-20'].sort_values(ascending=False)[0:10]
#Unsurprisingly, metrics like points/shots taken are the most higly correlated with the salary of a player
# Out:
# 2019-20    1.000000
# PTS        0.644255
# FGA        0.633378
# FG         0.629594
# FT         0.616106
# TOV        0.605957
# FTA        0.604035
# 2PA        0.589191
# MP         0.582983
# 2P         0.575604
# Name: 2019-20, dtype: float64

# %%
sns.scatterplot(data=twenty_stats_and_sal, x='PTS', y='2019-20')
#We see here that, generally, higher points = higher salary

# %%
sns.scatterplot(data=twenty_stats_and_sal, x='TOV', y='2019-20')
#Although not as linear as with points, it appears the more turnovers, the higher the salary
#However, this is likely a result of more minutes played

# %%
sns.barplot(x='FGA', y='2019-20', data=twenty_stats_and_sal)
#More attempted field goals typically means higher salary

# %% [markdown]
# Find players from all 5 years, output their averages

# %%
s=pd.concat([twenty_stats,nineteen_stats,eighteen_stats,seventeen_stats,sixteen_stats],axis=0)

# %% [markdown]
# Above, I am making a dataframe of the players that have been in the league for at least 5 years
# (so each will be in the last 5 years of dataframes). I will then add the players' salaries so I can
# see how their extended performances (not just within a year) affect their salaries
# This keeps me from having to drop rookies individually, as they will not meet the 5 year criteria to be in this dataset,
# and so will be dropped. The number of years is subject to change, and I am only using 5 as a starting point
# Furthermore, I will use the same method to predict for slaries before 2020 using past statistics

# %%
new_s = s[s['Player'].map(s['Player'].value_counts()) == 5]
new_s

#Here, we are grouping by players who are in all five of our datasets
#The next step will be to take their averages from the five seasons
# Out:
#         Rk             Player Season Pos   Age   Tm     G    GS    MP   FG  \
# 0      1.0       Steven Adams  19-20   C  26.0  OKC  63.0  63.0  26.7  4.5
# 2      3.0  LaMarcus Aldridge  19-20   C  34.0  SAS  53.0  53.0  33.1  7.4
# 8      9.0    Al-Farouq Aminu  19-20  PF  29.0  ORL  18.0   2.0  21.1  1.4
# 9     10.0    Justin Anderson  19-20  SF  26.0  BRK  10.0   1.0  10.7  1.0
# 10    11.0      Kyle Anderson  19-20  PF  26.0  MEM  67.0  28.0  19.9  2.3
# ..     ...                ...    ...  ..   ...  ...   ...   ...   ...  ...
# 567  466.0     Christian Wood  15-16  PF  20.0  PHI  17.0   0.0   8.5  1.3
# 570  469.0       Delon Wright  15-16  PG  23.0  TOR  27.0   1.0   8.5  1.3
# 575  474.0     Thaddeus Young  15-16  PF  27.0  BRK  73.0  73.0  33.0  6.8
# 576  475.0        Cody Zeller  15-16   C  23.0  CHO  73.0  60.0  24.3  3.2
# 577  476.0       Tyler Zeller  15-16   C  26.0  BOS  60.0   3.0  11.8  2.3
#
#      ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
new_s.dtypes
# Out:
# Rk        float64
# Player     object
# Season     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
aggregation_functions = {'Rk': 'first', 'Season': 'first', 'Pos': 'first', 'Age': 'mean', 'Tm': 'first', 'G': 'mean', 'GS': 'mean', 'MP': 'mean', 'FG': 'mean',
       'FGA': 'mean', 'FG%': 'mean', '3P': 'mean', '3PA': 'mean', '3P%': 'mean', '2P': 'mean', '2PA': 'mean', '2P%': 'mean', 'eFG%': 'mean', 
        'FT': 'mean', 'FTA': 'mean', 'FT%': 'mean', 'ORB': 'mean', 'DRB': 'mean', 'TRB': 'mean', 'AST': 'mean', 'STL': 'mean',
        'BLK': 'mean', 'TOV': 'mean', 'PF': 'mean',
       'PTS': 'mean'}
df_new = new_s.groupby(new_s['Player']).aggregate(aggregation_functions)
df_new
#Finding averages of all of the players over this five year span
# Out:
#                         Rk Season Pos   Age   Tm     G    GS     MP    FG  \
# Player
# Aaron Gordon         178.0  19-20  PF  22.0  ORL  71.2  61.2  30.36  5.26
# Al Horford           228.0  19-20   C  31.0  PHI  71.4  70.2  31.04  5.54
# Al-Farouq Aminu        9.0  19-20  PF  27.0  ORL  62.2  51.4  27.40  2.90
# Alec Burks            80.0  19-20  SG  26.0  TOT  53.4   9.4  21.16  3.48
# Alex Len             293.0  19-20   C  24.0  TOT  71.2  27.2  20.30  3.38
# ...                    ...    ...  ..   ...  ...   ...   ...    ...   ...
# Wayne Ellington      145.0  19-20  SG  30.0  NYK  60.8  19.0  22.40  3.10
# Wesley Matthews      320.0  19-20  SG  31.0  MIL  70.0  69.6  31.32  3.96
# Will Barton           29.0  19-20  SF  27.0  DEN  64.8  31.2  30.18  5.16
# Willie Cauley-Stein   94.0  19-20   C  24.0  TOT  69.8  47.6  23.18  3.98
# Zach LaVine          286.0  19-20  SG  22.0  CHI  55.2  45.2  32.36  7.06
#
# ...

# %%
sixteen_to_twenty_with_sal = pd.merge(left=df_new, right=twenty_salary_cond, how='left', on='Player')
#Adding 19-20 salary to dataframe

# %%
sixteen_to_twenty_with_sal['Player'].duplicated().value_counts()
#We have some duplicates we need to drop
# Out:
# False    216
# True      24
# Name: Player, dtype: int64

# %% [markdown]
# A quick aside: When I work with data from the other years (roll stats from multiple years into one dataframe) I will use the same method as I used above. Those years are not included here because I am not yet exactly sure which they will be.

# %%
sixteen_to_twenty_with_sal = sixteen_to_twenty_with_sal.drop_duplicates(subset=['Player'], keep='first')
#Dropping duplicates
#The rows in which the player's Total is listed is always the first listed, so we want to keep that one

# %%
sixteen_to_twenty_with_sal.isnull().sum()
# Out:
# Player     0
# Rk         0
# Season     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# 2019-20    4
# dtype: int64

# %%
sixteen_to_twenty_with_sal = sixteen_to_twenty_with_sal.dropna()
#Dropping rows where the salary is null
#Dropping from the whole dataframe because all of the null values are within the same column, so will be the same

# %%
sixteen_to_twenty_with_sal.shape
# Out:
# (212, 32)

# %%
sixteen_to_twenty_with_sal['2019-20'] = sixteen_to_twenty_with_sal['2019-20'].str.replace(',', '')
#Taking steps to turn column into integer

# %%
sixteen_to_twenty_with_sal['2019-20'] = sixteen_to_twenty_with_sal['2019-20'].str.replace('$', '')

# %%
sixteen_to_twenty_with_sal['2019-20'] = sixteen_to_twenty_with_sal['2019-20'].astype(int)
#Turning salary into an integer

# %%
sixteen_to_twenty_with_sal.corr()['2019-20'].sort_values(ascending=False)[0:10]
# Out:
# 2019-20    1.000000
# PTS        0.777871
# FG         0.767685
# FGA        0.747993
# MP         0.738304
# FT         0.706744
# GS         0.697379
# FTA        0.696733
# 2PA        0.684865
# TOV        0.677175
# Name: 2019-20, dtype: float64

# %%
sns.scatterplot(data=sixteen_to_twenty_with_sal, x='PTS', y='2019-20')
#Confirming what the correlation told us -- higher points per game = higher salary

# %%
sns.scatterplot(data=sixteen_to_twenty_with_sal, x='eFG%', y='2019-20')
#Interestingly, the highest salaries are towards the middle of the plot

# %%
sns.distplot(sixteen_to_twenty_with_sal['2019-20'])

# %% [markdown]
# The following data is at the bottom of the notebook because I am unsure if I will use it/how big a role it will have even if it does

# %%
fifteen_stats = pd.read_csv('./datasets/14-15_stats.csv')

# %%
fifteen_stats.insert(2, 'Season', '14-15')
#Adding season column

# %%
fifteen_stats = fifteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
new_fifteen_stats = pd.read_csv('./datasets/NEW_fifteen_stats.csv')

# %%
new_fifteen_stats.insert(2, 'Season', '14-15')

# %%
new_fifteen_stats = new_fifteen_stats.drop_duplicates(subset=['Player'], keep='first')

# %%
fourteen_stats = pd.read_csv('./datasets/13-14_stats.csv')

# %%
fourteen_stats.insert(2, 'Season', '13-14')
#Adding season column

# %%
fourteen_stats = fourteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
thirteen_stats = pd.read_csv('./datasets/12-13_stats.csv')

# %%
thirteen_stats.insert(2, 'Season', '12-13')
#Adding season column

# %%
thirteen_stats = thirteen_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
twelve_stats = pd.read_csv('./datasets/11-12_stats.csv')

# %%
twelve_stats.insert(2, 'Season', '11-12')
#Adding season column

# %%
twelve_stats = twelve_stats.drop_duplicates(subset=['Player'], keep='first')
#Since players who were traded have stats from each team they played for during the season AND their total stats from the 
#season, we need to drop the stats from each team because we only want stats from the whole season

# %%
eleven_stats = pd.read_csv('./datasets/10-11_stats.csv')

# %%
eleven_stats.insert(2, 'Season', '10-11')
#Adding season column

# %%
salaries_03_to_18 = pd.read_csv('./datasets/NBASalaryData03-17.csv')
salaries_03_to_18.head()

#At this point I am uncertain if I will use these salaries/how much (especially 2002-2010), but I have them here in 
#case I want to do some further exploration
# Out:
#                      team      salary            player position     season
# 0  Minnesota Timberwolves  25200000.0     Kevin Garnett       PF  2002-2003
# 1  Portland Trail Blazers  13500000.0  Damon Stoudamire       PG  2002-2003
# 2     Seattle SuperSonics  13080000.0       Gary Payton       PG  2002-2003
# 3     Seattle SuperSonics  12375000.0         Ray Allen       SG  2002-2003
# 4         New York Knicks  12375000.0  Latrell Sprewell       SG  2002-2003

# %%
salaries_03_to_18.shape
# Out:
# (6255, 5)

# %%
fifteen_salary = salaries_03_to_18[salaries_03_to_18.season == '2014-2015']
#This is how I will separate the large salary dataframe into year-by-year if I so choose
#The code will look the same as this for every year, just specifiying differently for each season

# %%
fifteen_salary.head()
# Out:
#                        team      salary         player position     season
# 4462     Los Angeles Lakers  23500000.0    Kobe Bryant       SF  2014-2015
# 4463  Oklahoma City Thunder  18995624.0   Kevin Durant       SF  2014-2015
# 4464          Chicago Bulls  18862876.0   Derrick Rose       PG  2014-2015
# 4465            LA Clippers  17674613.0  Blake Griffin       PF  2014-2015
# 4466      Memphis Grizzlies  16500000.0  Zach Randolph       PF  2014-2015

# %%
fifteen_salary.shape
# Out:
# (435, 5)

# %% [markdown]
# So just to give an idea of where I'm going from here:
#
# I plan to start modeling with the given features. Between correlation and subject knowledge, I have a feeling of which ones will generalize well and those that won't. I've chosen to not drop any of the features yet, and will instead do it when I set up a pipeline, just so I can be sure that I don't drop anything that could potentially help my model.
#
# I've designed most of the data so that I can predict salary based on multiple years past of statistics. I set up the data in this way because 1. it makes more sense to see what these players are earning after years of consistent performance, and 2. My goal from this project is to be able to better predict salary in the future, which I will need to do looking at past data.
#
# Some of my stretch goals will be: to add rookie contracts back into the model and see if I can get a consistent result, and creating a sort of scale that accounts for the increase/decrease in salary cap (and total salary paid around the league) each year.

# %% [markdown]
# All player statistics were taken from basketball-reference.com

# %% [markdown]
# Salary data from 2019-2020 was taken from basketball-reference.com
#
# https://www.basketball-reference.com/contracts/players.html

# %% [markdown]
# Salary data from 2002 to 2018 was taken from Kaggle from user Michael H, who scraped it from ESPN
#
# https://www.kaggle.com/hultm28/nba-player-salary-data-2002-2017

# %%
sixteen_to_twenty_with_sal.to_csv('./datasets/sixteen_to_twenty_with_sal.csv', index=False)

# %%
twenty_stats.to_csv('./datasets/twenty_STATS.csv', index=False)
nineteen_stats.to_csv('./datasets/nineteen_STATS.csv', index=False)
eighteen_stats.to_csv('./datasets/eighteen_STATS.csv', index=False)
seventeen_stats.to_csv('./datasets/seventeen_STATS.csv', index=False)
sixteen_stats.to_csv('./datasets/sixteen_STATS.csv', index=False)
fifteen_stats.to_csv('./datasets/fifteen_STATS.csv', index=False)
fourteen_stats.to_csv('./datasets/fourteen_STATS.csv', index=False)
thirteen_stats.to_csv('./datasets/thirteen_STATS.csv', index=False)
twelve_stats.to_csv('./datasets/twelve_STATS.csv', index=False)
eleven_stats.to_csv('./datasets/eleven_STATS.csv', index=False)

# %%
new_fifteen_stats.to_csv('./datasets/new_fifteen_stats.csv', index=False)

# %%
twenty_salary_cond.to_csv('./datasets/twenty_salary_cond.csv', index=False)

# %%
twenty_stats_and_sal.to_csv('./datasets/twenty_stats_and_sal.csv', index=False)

# %%
twenty_stats_and_sal.isnull().sum()
# Out:
# Player      0
# Season      0
# Pos         0
# Age         0
# Tm          0
# G           0
# GS          0
# MP          0
# FG          0
# FGA         0
# FG%         2
# 3P          0
# 3PA         0
# 3P%        21
# 2P          0
# 2PA         0
# 2P%         3
# eFG%        2
# FT          0
# FTA         0
# FT%        11
# ORB         0
# DRB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
# PTS         0
# 2019-20     0
# dtype: int64
